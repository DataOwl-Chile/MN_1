# %% [markdown]
# <p><img alt="DataOwl" width=150 src="http://gwsolutions.cl/Images/dataowl.png", align="left", hspace=0, vspace=5></p>
#
# <h1 align="center">Aplicación de la derivada</h1>
#
# <h4 align="center">Ecuaciones de una variable y Optimización</h4>
# <pre><div align="center"> La idea de este notebook es que sirva para iniciarse en conceptos
# matemáticos para aplicar la derivada numérica en la resolución
# de ecuaciones de una variable y optimización.</div>

# %% [markdown]
# # Aplicaciones de la derivada
#
#
# En clases anteriores, abordamos el problema de encontrar dónde una función se anula. En este Notebook veremos que las derivadas también nos pueden ayudar en este desafío, además de poder aplicarse en otros problemas, como la aproximación de una función mediante polinomios y la optimización de una función.

# %% [markdown]
# ## 5. Optimización (continuación)
#
# La clase anterior vimos la intuición tras la optimización de funciones derivables, mencionando que la derivada indica la pendiente de la función en un punto y cómo se interpreta el que ésta se anule en contraposición con el valor que adopta la segunda derivada. Hoy veremos dos métodos que pretenden resolver de forma eficiente el problema de encontrar mínimos locales de una función, y mencionaremos sus virtudes y defectos.
#
# ### 5.1 Método de Máximo Descenso
#
# <img  src="http://flennerhag.com/img/sgd/sgd_1.png" alt="Método de máximo descenso" width=280 align="center" hspace=0 vspace=5 padding:5px />
#
#
# Imaginemos que estamos en plena caminata en un cerro como el San Cristóbal, y una niebla muy densa nos impide ver en cualquier dirección. Queremos bajar para ubicarnos en un lugar más seguro, pero el cerro tiene varios accidentes topográficos, por lo cual es difícil adivinar qué camino seguir. Una estrategia para llegar abajo lo más rápido posible, es tantear el terreno cuidadosamente y movernos hacia donde notemos la mayor pendiente descendente; luego, volver a buscar dónde hay mayor pendiente descendente y avanzar, e iterar.
#
# Esta intuición da forma al **Método de Máximo Descenso**, el cual inicia desde un punto $x_0$ y a partir de él determina hacia dónde moverse, y con qué criterio establecer que se llegó a un mínimo aproximado. La secuencia de pasos está dada por
#
# $$x_{n+1}\ =\ x_n-\gamma\cdot f'(x_n)$$
#
# donde $\gamma>0$ es algún valor pequeño denominado *paso*, y el signo $-$ se ocupa de dar la dirección apropiada para el avance de nuestra sucesión de puntos. Generalmente, se usa $\gamma=dx$, el paso utilizado para calcular $f'(x)$ numéricamente, ya que economiza la cantidad de variables del programa. Como es un método de aproximación, es necesario establecer un umbral de aceptación, para tener una solución suficientemente buena en un tiempo acotado.

# %%
# Importando las librerías
# %matplotlib notebook
import numpy as np
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import experimento6 as ex

# %%
def f(x): # Alguna función de ejemplo
    return 0.5 - np.sin(2 * x)

def g(x): # Alguna función de ejemplo
    return (np.exp(-x ** 2) - x) / ((x + 1) ** 2 + (x - 1) ** 2)

def h(x):
    return x ** 4 - 3 * x ** 3 + 2

# %%
x = np.linspace(-10, 10, 1000)

plt.plot(x, h(x))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x0 = 7
dx = 0.01
error = 0.00001
xopt, yopt, cont = ex.descenso(g, x0, dx, error)
print(xopt, yopt, cont)
# Out:
# 1.5200000000001062 -0.2145931677442509 548

# %% [markdown]
# ### 5.2 Método de Newton
#
# Este método ya lo conocemos. Como queremos minimizar una función, deseamos encontrar un valor $\bar{x}$ en el cual $f(\bar{x})=0$. Se puede usar el método de Newton-Raphson (visto la clase anterior) pero esta vez aplicado a $f'(x)$, con lo cual el algoritmo estaría dado por la sucesión
#
# $$x_{n+1}\ =\ x_n-\frac{f'(x_n)}{f''(x_n)}$$
#
# El problema es que debemos tener una forma eficiente de calcular $f''$ en cada punto que se desee evaluar. En clases anteriores se ha calculado $f'$ mediante distintos métodos, uno de los cuales requería conocer $f$ de forma explícita, y en este caso es muy probable que no sepamos expresar la derivada de esta misma manera. Por lo tanto, recurriremos al cálculo numérico de las derivadas, pero sólo en el punto $x_n$ en que se está evaluando.
#
# Sabemos que se puede aproximar muy bien $f'$ como derivada *backward*, *forward* o central. Se puede definir la derivada de segundo orden por diferencia central como
#
# $$f_{\textrm{cent}}''(x)\ =\ \frac{f_{\textrm{for}}'(x)-f_{\textrm{back}}'(x)}{h}\ =\ \frac{\frac{f(x+h)-f(x)}{h}-\frac{f(x)-f(x-h)}{h}}{h}\ =\ \frac{f(x+h)-2f(x)+f(x-h)}{h^2}$$
#
# donde, por lo general, se utiliza $dx$ en vez de $h$. Más generalmente, iterando esta idea de calcular diferencias centrales, se puede deducir que
#
# $$f_{\textrm{cent}}^{[n]}(x)\ =\ \displaystyle\frac{1}{h^n}\sum_{k=0}^n(-1)^k\binom{n}{k}f\left(x+\left(\frac{n}{2}-k\right)h\right)$$
# donde $\binom{n}{k}=\frac{n!}{k!(n-k)!}$. Note que, si $n$ es impar, resulta conveniente promediar $f_{\textrm{cent}}^{[n]}\left(x+\frac{h}{2}\right)$ y $f_{\textrm{cent}}^{[n]}\left(x-\frac{h}{2}\right)$.
#
# El Método de Newton funciona bien cuando se escoge un valor inicial $x_0$ tal que tanto éste como el óptimo $\bar{x}$ pertenezcan a un intervalo $[a,b]$ tal que $f$ es convexa en él, es decir, tal que $f''(x)\ge 0$ para $x\in[a,b]$.

# %%
x0 = 10
dx = 0.001
error = 0.00001

xopt, yopt, dyopt = ex.newtonoptim(h, x0, dx, error)
print(xopt, yopt, dyopt)
# Out:
# Solución tras  8  iteraciones.
# 2.249999939956084 -6.542968749999961 4.7841108852253456e-06

# %% [markdown]
# ## 6. Ajuste de datos
#
# Sin entrar en mucho detalle, la interpolación de datos pretende completar la información entre datos que podríamos considerar insuficientes. Existen varias formas de hacerlo, como la interpolación lineal (en que se une los datos observados con rectas), la interpolación polinomial (como la interpolación de Legendre) que es bastante inestable conforme aumenta la cantidad de puntos observados y la interpolación polinomial por tramos(como el spline cúbico). En esta breve sección, veremos cómo aplicar la interpolación con spline cúbico, pretendiendo comparar datos mensuales con datos semanales y diarios en el índice del dólar.
#
# Una de las virtudes que se espera introducir, es que se pueda predecir con suficiente precisión datos que no tenemos (en el caso de los datos mensuales, no tenemos información semanal, diaria o continua). Además, la función interpoladora va a ser diferenciable, lo cual es imposible de tener de los datos reales, pues éstos se miden de forma discreta.
#
# Finalmente, también mostraremos por primera vez las librerías **Scipy** y **csv**, para el tratamiento científico de datos y para la lectura de datos en formato .csv, respectivamente.

# %%
import csv


# Leemos datos mensuales

with open('USDMensual.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        print(row)
# Out:
# OrderedDict([('ï»¿"Date"', 'Jul 20'), ('Price', '96.74'), ('Open', '97.39'), ('High', '97.61'), ('Low', '96.24'), ('Vol.', '-'), ('Change %', '-0.67%')])
# OrderedDict([('ï»¿"Date"', 'Jun 20'), ('Price', '97.39'), ('Open', '98.20'), ('High', '98.24'), ('Low', '95.72'), ('Vol.', '-'), ('Change %', '-0.97%')])
# OrderedDict([('ï»¿"Date"', 'May 20'), ('Price', '98.34'), ('Open', '99.12'), ('High', '100.55'), ('Low', '97.94'), ('Vol.', '-'), ('Change %', '-1.23%')])
# OrderedDict([('ï»¿"Date"', 'Apr 20'), ('Price', '99.57'), ('Open', '98.98'), ('High', '100.93'), ('Low', '98.81'), ('Vol.', '-'), ('Change %', '0.52%')])
# OrderedDict([('ï»¿"Date"', 'Mar 20'), ('Price', '99.05'), ('Open', '98.12'), ('High', '102.99'), ('Low', '94.66'), ('Vol.', '-'), ('Change %', '0.94%')])
# OrderedDict([('ï»¿"Date"', 'Feb 20'), ('Price', '98.13'), ('Open', '97.37'), ('High', '99.91'), ('Low', '97.37'), ('Vol.', '-'), ('Change %', '0.76%')])
# OrderedDict([('ï»¿"Date"', 'Jan 20'), ('Price', '97.39'), ('Open', '96.50'), ('High', '98.19'), ('Low', '96.39'), ('Vol.', '-'), ('Change %', '1.04%')])
# OrderedDict([('ï»¿"Date"', 'Dec 19'), ('Price', '96.39'), ('Open', '98.27'), ('High', '98.38'), ('Low', '96.36'), ('Vol.', '-'), ('Change %', '-1.91%')])
# OrderedDict([('ï»¿"Date"', 'Nov 19'), ('Price', '98.27'), ('Open', '97.30'), ('High', '98.54'), ('Low', '97.11'), ('Vol.', '-'), ('Change %', '0.95%')])
# OrderedDict([('ï»¿"Date"', 'Oct 19'), ('Price', '97.35'), ('Open', '99.40'), ('High', '99.67'), ('Low', '97.14'), ('Vol.', '-'), ('Change %', '-2.04%')])
# OrderedDict([('ï»¿"Date"', 'Sep 19'), ('Price', '99.38'), ('Open', '98.83'), ('High', '99.46'), ('Low', '97.86'), ('Vol.', '-'), ('Change %', '0.47%')])
# OrderedDict([('ï»¿"Date"', 'Aug 19'), ('Price', '98.92'), ('Open', '98.59'), ('High', '99.02'), ('Low', '97.03'), ('Vol.', '-'), ('Change %', '0.41%')])
# OrderedDict([('ï»¿"Date"', 'Jul 19'), ('Price', '98.52'), ('Open', '96.25'), ('High', '98.68'), ('Low', '96.25'), ('Vol.', '-'), ('Change %', '2.49%')])
# OrderedDict([('ï»¿"Date"', 'Jun 19'), ('Price', '96.13'), ('Open', '97.64'), ('High', '97.80'), ('Low', '95.84'), ('Vol.', '-'), ('Change %', '-1.66%')])
# OrderedDict([('ï»¿"Date"', 'May 19'), ('Price', '97.75'), ('Open', '97.53'), ('High', '98.37'), ('Low', '97.03'), ('Vol.', '-'), ('Change %', '0.28%')])
# OrderedDict([('ï»¿"Date"', 'Apr 19'), ('Price', '97.48'), ('Open', '97.18'), ('High', '98.33'), ('Low', '96.75'), ('Vol.', '-'), ('Change %', '0.21%')])
# OrderedDict([('ï»¿"Date"', 'Mar 19'), ('Price', '97.28'), ('Open', '96.22'), ('High', '97.71'), ('Low', '95.74'), ('Vol.', '-'), ('Change %', '1.16%')])
# OrderedDict([('ï»¿"Date"', 'Feb 19'), ('Price', '96.16'), ('Open', '95.55'), ('High', '97.37'), ('Low', '95.40'), ('Vol.', '-'), ('Change %', '0.61%')])
# OrderedDict([('ï»¿"Date"', 'Jan 19'), ('Price', '95.58'), ('Open', '96.15'), ('High', '96.96'), ('Low', '95.03'), ('Vol.', '-'), ('Change %', '-0.61%')])
# OrderedDict([('ï»¿"Date"', 'Dec 18'), ('Price', '96.17'), ('Open', '97.13'), ('High', '97.71'), ('Low', '96.00'), ('Vol.', '-'), ('Change %', '-1.13%')])
# OrderedDict([('ï»¿"Date"', 'Nov 18'), ('Price', '97.27'), ('Open', '97.08'), ('High', '97.69'), ('Low', '95.68'), ('Vol.', '-'), ('Change %', '0.14%')])
# OrderedDict([('ï»¿"Date"', 'Oct 18'), ('Price', '97.13'), ('Open', '95.11'), ('High', '97.20'), ('Low', '94.79'), ('Vol.', '-'), ('Change %', '2.10%')])
# OrderedDict([('ï»¿"Date"', 'Sep 18'), ('Price', '95.13'), ('Open', '95.19'), ('High', '95.74'), ('Low', '93.81'), ('Vol.', '-'), ('Change %', '-0.01%')])
# OrderedDict([('ï»¿"Date"', 'Aug 18'), ('Price', '95.14'), ('Open', '94.56'), ('High', '96.98'), ('Low', '94.43'), ('Vol.', '-'), ('Change %', '0.69%')])
# OrderedDict([('ï»¿"Date"', 'Jul 18'), ('Price', '94.49'), ('Open', '94.63'), ('High', '95.65'), ('Low', '93.71'), ('Vol.', '-'), ('Change %', '-0.16%')])
# OrderedDict([('ï»¿"Date"', 'Jun 18'), ('Price', '94.64'), ('Open', '93.95'), ('High', '95.53'), ('Low', '93.19'), ('Vol.', '-'), ('Change %', '0.70%')])
# OrderedDict([('ï»¿"Date"', 'May 18'), ('Price', '93.98'), ('Open', '91.81'), ('High', '95.03'), ('Low', '91.80'), ('Vol.', '-'), ('Change %', '2.33%')])
# OrderedDict([('ï»¿"Date"', 'Apr 18'), ('Price', '91.84'), ('Open', '89.97'), ('High', '91.99'), ('Low', '89.23'), ('Vol.', '-'), ('Change %', '2.08%')])
# OrderedDict([('ï»¿"Date"', 'Mar 18'), ('Price', '89.97'), ('Open', '90.67'), ('High', '90.93'), ('Low', '88.94'), ('Vol.', '-'), ('Change %', '-0.71%')])
# OrderedDict([('ï»¿"Date"', 'Feb 18'), ('Price', '90.61'), ('Open', '89.04'), ('High', '90.70'), ('Low', '88.25'), ('Vol.', '-'), ('Change %', '1.66%')])
# OrderedDict([('ï»¿"Date"', 'Jan 18'), ('Price', '89.13'), ('Open', '92.24'), ('High', '92.64'), ('Low', '88.44'), ('Vol.', '-'), ('Change %', '-3.25%')])
# OrderedDict([('ï»¿"Date"', 'Dec 17'), ('Price', '92.12'), ('Open', '93.03'), ('High', '94.22'), ('Low', '92.08'), ('Vol.', '-'), ('Change %', '-1.00%')])
# OrderedDict([('ï»¿"Date"', 'Nov 17'), ('Price', '93.05'), ('Open', '94.55'), ('High', '95.15'), ('Low', '92.50'), ('Vol.', '-'), ('Change %', '-1.59%')])
# OrderedDict([('ï»¿"Date"', 'Oct 17'), ('Price', '94.55'), ('Open', '93.22'), ('High', '95.15'), ('Low', '92.75'), ('Vol.', '-'), ('Change %', '1.58%')])
# OrderedDict([('ï»¿"Date"', 'Sep 17'), ('Price', '93.08'), ('Open', '92.61'), ('High', '93.67'), ('Low', '91.01'), ('Vol.', '-'), ('Change %', '0.44%')])
# OrderedDict([('ï»¿"Date"', 'Aug 17'), ('Price', '92.67'), ('Open', '92.89'), ('High', '94.14'), ('Low', '91.62'), ('Vol.', '-'), ('Change %', '-0.20%')])
# OrderedDict([('ï»¿"Date"', 'Jul 17'), ('Price', '92.86'), ('Open', '95.65'), ('High', '96.51'), ('Low', '92.78'), ('Vol.', '-'), ('Change %', '-2.90%')])
# OrderedDict([('ï»¿"Date"', 'Jun 17'), ('Price', '95.63'), ('Open', '96.99'), ('High', '97.87'), ('Low', '95.47'), ('Vol.', '-'), ('Change %', '-1.33%')])
# OrderedDict([('ï»¿"Date"', 'May 17'), ('Price', '96.92'), ('Open', '98.93'), ('High', '99.89'), ('Low', '96.80'), ('Vol.', '-'), ('Change %', '-2.15%')])
# OrderedDict([('ï»¿"Date"', 'Apr 17'), ('Price', '99.05'), ('Open', '100.50'), ('High', '101.34'), ('Low', '98.69'), ('Vol.', '-'), ('Change %', '-1.30%')])
# OrderedDict([('ï»¿"Date"', 'Mar 17'), ('Price', '100.35'), ('Open', '101.43'), ('High', '102.26'), ('Low', '98.86'), ('Vol.', '-'), ('Change %', '-0.76%')])
# OrderedDict([('ï»¿"Date"', 'Feb 17'), ('Price', '101.12'), ('Open', '99.56'), ('High', '101.76'), ('Low', '99.23'), ('Vol.', '-'), ('Change %', '1.62%')])
# OrderedDict([('ï»¿"Date"', 'Jan 17'), ('Price', '99.51'), ('Open', '102.38'), ('High', '103.82'), ('Low', '99.43'), ('Vol.', '-'), ('Change %', '-2.64%')])
# OrderedDict([('ï»¿"Date"', 'Dec 16'), ('Price', '102.21'), ('Open', '101.52'), ('High', '103.65'), ('Low', '99.43'), ('Vol.', '-'), ('Change %', '0.70%')])
# OrderedDict([('ï»¿"Date"', 'Nov 16'), ('Price', '101.50'), ('Open', '98.39'), ('High', '102.05'), ('Low', '95.89'), ('Vol.', '-'), ('Change %', '3.11%')])
# OrderedDict([('ï»¿"Date"', 'Oct 16'), ('Price', '98.44'), ('Open', '95.54'), ('High', '99.12'), ('Low', '95.46'), ('Vol.', '-'), ('Change %', '3.12%')])
# OrderedDict([('ï»¿"Date"', 'Sep 16'), ('Price', '95.46'), ('Open', '95.98'), ('High', '96.33'), ('Low', '94.47'), ('Vol.', '-'), ('Change %', '-0.58%')])
# OrderedDict([('ï»¿"Date"', 'Aug 16'), ('Price', '96.02'), ('Open', '95.59'), ('High', '96.52'), ('Low', '94.08'), ('Vol.', '-'), ('Change %', '0.51%')])
# OrderedDict([('ï»¿"Date"', 'Jul 16'), ('Price', '95.53'), ('Open', '95.89'), ('High', '97.57'), ('Low', '95.34'), ('Vol.', '-'), ('Change %', '-0.63%')])
# OrderedDict([('ï»¿"Date"', 'Jun 16'), ('Price', '96.14'), ('Open', '95.81'), ('High', '96.70'), ('Low', '93.02'), ('Vol.', '-'), ('Change %', '0.26%')])
# OrderedDict([('ï»¿"Date"', 'May 16'), ('Price', '95.89'), ('Open', '93.02'), ('High', '95.97'), ('Low', '91.92'), ('Vol.', '-'), ('Change %', '3.02%')])
# OrderedDict([('ï»¿"Date"', 'Apr 16'), ('Price', '93.08'), ('Open', '94.64'), ('High', '95.20'), ('Low', '93.01'), ('Vol.', '-'), ('Change %', '-1.60%')])
# OrderedDict([('ï»¿"Date"', 'Mar 16'), ('Price', '94.59'), ('Open', '98.18'), ('High', '98.58'), ('Low', '94.32'), ('Vol.', '-'), ('Change %', '-3.69%')])
# OrderedDict([('ï»¿"Date"', 'Feb 16'), ('Price', '98.21'), ('Open', '99.55'), ('High', '99.63'), ('Low', '95.24'), ('Vol.', '-'), ('Change %', '-1.41%')])
# OrderedDict([('ï»¿"Date"', 'Jan 16'), ('Price', '99.61'), ('Open', '98.59'), ('High', '99.83'), ('Low', '98.05'), ('Vol.', '-'), ('Change %', '0.99%')])
# OrderedDict([('ï»¿"Date"', 'Dec 15'), ('Price', '98.63'), ('Open', '100.23'), ('High', '100.51'), ('Low', '97.19'), ('Vol.', '-'), ('Change %', '-1.54%')])
# OrderedDict([('ï»¿"Date"', 'Nov 15'), ('Price', '100.17'), ('Open', '96.69'), ('High', '100.31'), ('Low', '96.64'), ('Vol.', '-'), ('Change %', '3.32%')])
# OrderedDict([('ï»¿"Date"', 'Oct 15'), ('Price', '96.95'), ('Open', '96.27'), ('High', '97.82'), ('Low', '93.81'), ('Vol.', '-'), ('Change %', '0.62%')])
# OrderedDict([('ï»¿"Date"', 'Sep 15'), ('Price', '96.35'), ('Open', '95.93'), ('High', '96.70'), ('Low', '94.06'), ('Vol.', '-'), ('Change %', '0.55%')])
# OrderedDict([('ï»¿"Date"', 'Aug 15'), ('Price', '95.82'), ('Open', '97.22'), ('High', '98.33'), ('Low', '92.62'), ('Vol.', '-'), ('Change %', '-1.56%')])
# OrderedDict([('ï»¿"Date"', 'Jul 15'), ('Price', '97.34'), ('Open', '95.58'), ('High', '98.15'), ('Low', '95.45'), ('Vol.', '-'), ('Change %', '1.95%')])
# OrderedDict([('ï»¿"Date"', 'Jun 15'), ('Price', '95.48'), ('Open', '96.90'), ('High', '97.68'), ('Low', '93.56'), ('Vol.', '-'), ('Change %', '-1.48%')])
# OrderedDict([('ï»¿"Date"', 'May 15'), ('Price', '96.91'), ('Open', '94.83'), ('High', '97.78'), ('Low', '93.13'), ('Vol.', '-'), ('Change %', '2.44%')])
# OrderedDict([('ï»¿"Date"', 'Apr 15'), ('Price', '94.60'), ('Open', '98.42'), ('High', '99.99'), ('Low', '94.40'), ('Vol.', '-'), ('Change %', '-3.82%')])
# OrderedDict([('ï»¿"Date"', 'Mar 15'), ('Price', '98.36'), ('Open', '95.38'), ('High', '100.39'), ('Low', '95.06'), ('Vol.', '-'), ('Change %', '3.19%')])
# OrderedDict([('ï»¿"Date"', 'Feb 15'), ('Price', '95.32'), ('Open', '94.58'), ('High', '95.85'), ('Low', '93.25'), ('Vol.', '-'), ('Change %', '0.55%')])
# OrderedDict([('ï»¿"Date"', 'Jan 15'), ('Price', '94.80'), ('Open', '90.36'), ('High', '95.48'), ('Low', '90.33'), ('Vol.', '-'), ('Change %', '5.02%')])
# OrderedDict([('ï»¿"Date"', 'Dec 14'), ('Price', '90.27'), ('Open', '88.16'), ('High', '90.33'), ('Low', '87.63'), ('Vol.', '-'), ('Change %', '2.16%')])
# OrderedDict([('ï»¿"Date"', 'Nov 14'), ('Price', '88.36'), ('Open', '87.08'), ('High', '88.44'), ('Low', '86.88'), ('Vol.', '-'), ('Change %', '1.66%')])
# OrderedDict([('ï»¿"Date"', 'Oct 14'), ('Price', '86.92'), ('Open', '85.92'), ('High', '87.13'), ('Low', '84.47'), ('Vol.', '-'), ('Change %', '1.14%')])
# OrderedDict([('ï»¿"Date"', 'Sep 14'), ('Price', '85.94'), ('Open', '82.77'), ('High', '86.22'), ('Low', '82.67'), ('Vol.', '-'), ('Change %', '3.85%')])
# OrderedDict([('ï»¿"Date"', 'Aug 14'), ('Price', '82.75'), ('Open', '81.44'), ('High', '82.75'), ('Low', '81.19'), ('Vol.', '-'), ('Change %', '1.58%')])
# OrderedDict([('ï»¿"Date"', 'Jul 14'), ('Price', '81.46'), ('Open', '79.79'), ('High', '81.57'), ('Low', '79.74'), ('Vol.', '-'), ('Change %', '2.11%')])
# OrderedDict([('ï»¿"Date"', 'Jun 14'), ('Price', '79.78'), ('Open', '80.36'), ('High', '81.02'), ('Low', '79.76'), ('Vol.', '-'), ('Change %', '-0.73%')])
# OrderedDict([('ï»¿"Date"', 'May 14'), ('Price', '80.37'), ('Open', '79.52'), ('High', '80.58'), ('Low', '78.91'), ('Vol.', '-'), ('Change %', '1.13%')])
# OrderedDict([('ï»¿"Date"', 'Apr 14'), ('Price', '79.47'), ('Open', '80.10'), ('High', '80.60'), ('Low', '79.33'), ('Vol.', '-'), ('Change %', '-0.79%')])
# OrderedDict([('ï»¿"Date"', 'Mar 14'), ('Price', '80.10'), ('Open', '79.90'), ('High', '80.35'), ('Low', '79.27'), ('Vol.', '-'), ('Change %', '0.51%')])
# OrderedDict([('ï»¿"Date"', 'Feb 14'), ('Price', '79.69'), ('Open', '81.28'), ('High', '81.32'), ('Low', '79.69'), ('Vol.', '-'), ('Change %', '-1.99%')])
# OrderedDict([('ï»¿"Date"', 'Jan 14'), ('Price', '81.31'), ('Open', '80.21'), ('High', '81.39'), ('Low', '80.08'), ('Vol.', '-'), ('Change %', '1.60%')])
# OrderedDict([('ï»¿"Date"', 'Dec 13'), ('Price', '80.03'), ('Open', '80.66'), ('High', '80.99'), ('Low', '79.69'), ('Vol.', '-'), ('Change %', '-0.81%')])
# OrderedDict([('ï»¿"Date"', 'Nov 13'), ('Price', '80.68'), ('Open', '80.23'), ('High', '81.48'), ('Low', '80.25'), ('Vol.', '-'), ('Change %', '0.61%')])
# OrderedDict([('ï»¿"Date"', 'Oct 13'), ('Price', '80.19'), ('Open', '80.27'), ('High', '80.75'), ('Low', '79.00'), ('Vol.', '-'), ('Change %', '-0.04%')])
# OrderedDict([('ï»¿"Date"', 'Sep 13'), ('Price', '80.22'), ('Open', '82.05'), ('High', '82.67'), ('Low', '80.03'), ('Vol.', '-'), ('Change %', '-2.28%')])
# OrderedDict([('ï»¿"Date"', 'Aug 13'), ('Price', '82.09'), ('Open', '81.66'), ('High', '82.49'), ('Low', '80.75'), ('Vol.', '-'), ('Change %', '0.79%')])
# OrderedDict([('ï»¿"Date"', 'Jul 13'), ('Price', '81.45'), ('Open', '83.18'), ('High', '84.75'), ('Low', '81.41'), ('Vol.', '-'), ('Change %', '-2.03%')])
# OrderedDict([('ï»¿"Date"', 'Jun 13'), ('Price', '83.14'), ('Open', '83.32'), ('High', '83.38'), ('Low', '80.50'), ('Vol.', '-'), ('Change %', '-0.14%')])
# OrderedDict([('ï»¿"Date"', 'May 13'), ('Price', '83.26'), ('Open', '81.71'), ('High', '84.50'), ('Low', '81.33'), ('Vol.', '-'), ('Change %', '1.85%')])
# OrderedDict([('ï»¿"Date"', 'Apr 13'), ('Price', '81.75'), ('Open', '83.05'), ('High', '83.49'), ('Low', '81.60'), ('Vol.', '-'), ('Change %', '-1.77%')])
# OrderedDict([('ï»¿"Date"', 'Mar 13'), ('Price', '83.22'), ('Open', '81.92'), ('High', '83.30'), ('Low', '81.78'), ('Vol.', '-'), ('Change %', '1.55%')])
# OrderedDict([('ï»¿"Date"', 'Feb 13'), ('Price', '81.95'), ('Open', '79.13'), ('High', '82.00'), ('Low', '78.92'), ('Vol.', '-'), ('Change %', '3.46%')])
# OrderedDict([('ï»¿"Date"', 'Jan 13'), ('Price', '79.21'), ('Open', '79.69'), ('High', '80.87'), ('Low', '79.13'), ('Vol.', '-'), ('Change %', '-0.70%')])
# OrderedDict([('ï»¿"Date"', 'Dec 12'), ('Price', '79.77'), ('Open', '80.24'), ('High', '80.66'), ('Low', '79.01'), ('Vol.', '-'), ('Change %', '-0.47%')])
# OrderedDict([('ï»¿"Date"', 'Nov 12'), ('Price', '80.15'), ('Open', '79.95'), ('High', '81.45'), ('Low', '79.86'), ('Vol.', '-'), ('Change %', '0.29%')])
# OrderedDict([('ï»¿"Date"', 'Oct 12'), ('Price', '79.92'), ('Open', '79.95'), ('High', '80.33'), ('Low', '78.94'), ('Vol.', '-'), ('Change %', '-0.03%')])
# OrderedDict([('ï»¿"Date"', 'Sep 12'), ('Price', '79.94'), ('Open', '81.29'), ('High', '81.67'), ('Low', '78.60'), ('Vol.', '-'), ('Change %', '-1.56%')])
# OrderedDict([('ï»¿"Date"', 'Aug 12'), ('Price', '81.21'), ('Open', '82.70'), ('High', '83.51'), ('Low', '80.96'), ('Vol.', '-'), ('Change %', '-1.73%')])
# OrderedDict([('ï»¿"Date"', 'Jul 12'), ('Price', '82.64'), ('Open', '81.56'), ('High', '84.10'), ('Low', '81.53'), ('Vol.', '-'), ('Change %', '1.24%')])
# OrderedDict([('ï»¿"Date"', 'Jun 12'), ('Price', '81.63'), ('Open', '83.07'), ('High', '83.54'), ('Low', '81.19'), ('Vol.', '-'), ('Change %', '-1.70%')])
# OrderedDict([('ï»¿"Date"', 'May 12'), ('Price', '83.04'), ('Open', '78.78'), ('High', '83.22'), ('Low', '78.60'), ('Vol.', '-'), ('Change %', '5.41%')])
# OrderedDict([('ï»¿"Date"', 'Apr 12'), ('Price', '78.78'), ('Open', '78.89'), ('High', '80.18'), ('Low', '78.64'), ('Vol.', '-'), ('Change %', '-0.28%')])
# OrderedDict([('ï»¿"Date"', 'Mar 12'), ('Price', '79.00'), ('Open', '78.77'), ('High', '80.74'), ('Low', '78.63'), ('Vol.', '-'), ('Change %', '0.33%')])
# OrderedDict([('ï»¿"Date"', 'Feb 12'), ('Price', '78.74'), ('Open', '79.32'), ('High', '80.12'), ('Low', '78.09'), ('Vol.', '-'), ('Change %', '-0.69%')])
# OrderedDict([('ï»¿"Date"', 'Jan 12'), ('Price', '79.29'), ('Open', '80.28'), ('High', '81.78'), ('Low', '78.74'), ('Vol.', '-'), ('Change %', '-1.11%')])
# OrderedDict([('ï»¿"Date"', 'Dec 11'), ('Price', '80.18'), ('Open', '78.33'), ('High', '80.85'), ('Low', '77.97'), ('Vol.', '-'), ('Change %', '2.30%')])
# OrderedDict([('ï»¿"Date"', 'Nov 11'), ('Price', '78.38'), ('Open', '76.56'), ('High', '79.70'), ('Low', '76.46'), ('Vol.', '-'), ('Change %', '2.90%')])
# OrderedDict([('ï»¿"Date"', 'Oct 11'), ('Price', '76.17'), ('Open', '79.02'), ('High', '79.84'), ('Low', '74.72'), ('Vol.', '-'), ('Change %', '-3.03%')])
# OrderedDict([('ï»¿"Date"', 'Sep 11'), ('Price', '78.55'), ('Open', '74.17'), ('High', '78.86'), ('Low', '74.15'), ('Vol.', '-'), ('Change %', '5.98%')])
# OrderedDict([('ï»¿"Date"', 'Aug 11'), ('Price', '74.12'), ('Open', '73.81'), ('High', '75.42'), ('Low', '73.45'), ('Vol.', '-'), ('Change %', '0.30%')])
# OrderedDict([('ï»¿"Date"', 'Jul 11'), ('Price', '73.90'), ('Open', '74.45'), ('High', '76.72'), ('Low', '73.42'), ('Vol.', '-'), ('Change %', '-0.54%')])
# OrderedDict([('ï»¿"Date"', 'Jun 11'), ('Price', '74.30'), ('Open', '74.43'), ('High', '76.02'), ('Low', '73.51'), ('Vol.', '-'), ('Change %', '-0.46%')])
# OrderedDict([('ï»¿"Date"', 'May 11'), ('Price', '74.64'), ('Open', '72.99'), ('High', '76.37'), ('Low', '72.70'), ('Vol.', '-'), ('Change %', '2.34%')])
# OrderedDict([('ï»¿"Date"', 'Apr 11'), ('Price', '72.93'), ('Open', '76.05'), ('High', '76.61'), ('Low', '72.83'), ('Vol.', '-'), ('Change %', '-3.86%')])
# OrderedDict([('ï»¿"Date"', 'Mar 11'), ('Price', '75.86'), ('Open', '76.86'), ('High', '77.38'), ('Low', '75.34'), ('Vol.', '-'), ('Change %', '-1.34%')])
# OrderedDict([('ï»¿"Date"', 'Feb 11'), ('Price', '76.89'), ('Open', '77.61'), ('High', '78.87'), ('Low', '76.76'), ('Vol.', '-'), ('Change %', '-1.08%')])
# OrderedDict([('ï»¿"Date"', 'Jan 11'), ('Price', '77.73'), ('Open', '79.14'), ('High', '81.31'), ('Low', '77.54'), ('Vol.', '-'), ('Change %', '-1.64%')])
# OrderedDict([('ï»¿"Date"', 'Dec 10'), ('Price', '79.03'), ('Open', '81.26'), ('High', '81.36'), ('Low', '78.78'), ('Vol.', '-'), ('Change %', '-2.66%')])
# OrderedDict([('ï»¿"Date"', 'Nov 10'), ('Price', '81.19'), ('Open', '76.97'), ('High', '81.44'), ('Low', '75.63'), ('Vol.', '-'), ('Change %', '5.07%')])
# OrderedDict([('ï»¿"Date"', 'Oct 10'), ('Price', '77.27'), ('Open', '78.80'), ('High', '78.83'), ('Low', '76.14'), ('Vol.', '-'), ('Change %', '-1.84%')])
# OrderedDict([('ï»¿"Date"', 'Sep 10'), ('Price', '78.72'), ('Open', '83.09'), ('High', '83.22'), ('Low', '78.41'), ('Vol.', '-'), ('Change %', '-5.38%')])
# OrderedDict([('ï»¿"Date"', 'Aug 10'), ('Price', '83.20'), ('Open', '81.50'), ('High', '83.56'), ('Low', '80.08'), ('Vol.', '-'), ('Change %', '2.04%')])
# OrderedDict([('ï»¿"Date"', 'Jul 10'), ('Price', '81.54'), ('Open', '86.10'), ('High', '86.26'), ('Low', '81.46'), ('Vol.', '-'), ('Change %', '-5.21%')])
# OrderedDict([('ï»¿"Date"', 'Jun 10'), ('Price', '86.02'), ('Open', '86.58'), ('High', '88.71'), ('Low', '85.09'), ('Vol.', '-'), ('Change %', '-0.66%')])
# OrderedDict([('ï»¿"Date"', 'May 10'), ('Price', '86.59'), ('Open', '81.84'), ('High', '87.46'), ('Low', '81.83'), ('Vol.', '-'), ('Change %', '5.77%')])
# OrderedDict([('ï»¿"Date"', 'Apr 10'), ('Price', '81.87'), ('Open', '81.04'), ('High', '82.71'), ('Low', '80.03'), ('Vol.', '-'), ('Change %', '0.99%')])
# OrderedDict([('ï»¿"Date"', 'Mar 10'), ('Price', '81.07'), ('Open', '80.42'), ('High', '82.24'), ('Low', '79.51'), ('Vol.', '-'), ('Change %', '0.88%')])
# OrderedDict([('ï»¿"Date"', 'Feb 10'), ('Price', '80.36'), ('Open', '79.46'), ('High', '81.34'), ('Low', '78.68'), ('Vol.', '-'), ('Change %', '1.13%')])
# OrderedDict([('ï»¿"Date"', 'Jan 10'), ('Price', '79.46'), ('Open', '77.92'), ('High', '79.50'), ('Low', '76.60'), ('Vol.', '-'), ('Change %', '2.05%')])
# OrderedDict([('ï»¿"Date"', 'Dec 09'), ('Price', '77.86'), ('Open', '74.71'), ('High', '78.45'), ('Low', '74.27'), ('Vol.', '-'), ('Change %', '4.12%')])
# OrderedDict([('ï»¿"Date"', 'Nov 09'), ('Price', '74.78'), ('Open', '76.37'), ('High', '76.82'), ('Low', '74.17'), ('Vol.', '-'), ('Change %', '-1.99%')])
# OrderedDict([('ï»¿"Date"', 'Oct 09'), ('Price', '76.30'), ('Open', '76.65'), ('High', '77.47'), ('Low', '74.94'), ('Vol.', '-'), ('Change %', '-0.46%')])
# OrderedDict([('ï»¿"Date"', 'Sep 09'), ('Price', '76.65'), ('Open', '78.11'), ('High', '78.94'), ('Low', '75.83'), ('Vol.', '-'), ('Change %', '-1.94%')])
# OrderedDict([('ï»¿"Date"', 'Aug 09'), ('Price', '78.17'), ('Open', '78.25'), ('High', '79.51'), ('Low', '77.43'), ('Vol.', '-'), ('Change %', '-0.23%')])
# OrderedDict([('ï»¿"Date"', 'Jul 09'), ('Price', '78.35'), ('Open', '80.12'), ('High', '80.89'), ('Low', '78.22'), ('Vol.', '-'), ('Change %', '-2.26%')])
# OrderedDict([('ï»¿"Date"', 'Jun 09'), ('Price', '80.16'), ('Open', '79.35'), ('High', '81.47'), ('Low', '78.33'), ('Vol.', '-'), ('Change %', '1.17%')])
# OrderedDict([('ï»¿"Date"', 'May 09'), ('Price', '79.23'), ('Open', '84.72'), ('High', '84.87'), ('Low', '79.18'), ('Vol.', '-'), ('Change %', '-6.59%')])
# OrderedDict([('ï»¿"Date"', 'Apr 09'), ('Price', '84.82'), ('Open', '85.53'), ('High', '86.87'), ('Low', '83.73'), ('Vol.', '-'), ('Change %', '-0.81%')])
# OrderedDict([('ï»¿"Date"', 'Mar 09'), ('Price', '85.51'), ('Open', '88.58'), ('High', '89.62'), ('Low', '82.63'), ('Vol.', '-'), ('Change %', '-3.02%')])
# OrderedDict([('ï»¿"Date"', 'Feb 09'), ('Price', '88.17'), ('Open', '86.08'), ('High', '88.49'), ('Low', '84.47'), ('Vol.', '-'), ('Change %', '2.73%')])
# OrderedDict([('ï»¿"Date"', 'Jan 09'), ('Price', '85.83'), ('Open', '81.18'), ('High', '86.81'), ('Low', '80.85'), ('Vol.', '-'), ('Change %', '5.77%')])
# OrderedDict([('ï»¿"Date"', 'Dec 08'), ('Price', '81.15'), ('Open', '86.42'), ('High', '87.70'), ('Low', '77.69'), ('Vol.', '-'), ('Change %', '-6.21%')])
# OrderedDict([('ï»¿"Date"', 'Nov 08'), ('Price', '86.52'), ('Open', '85.81'), ('High', '88.46'), ('Low', '83.90'), ('Vol.', '-'), ('Change %', '1.04%')])
# OrderedDict([('ï»¿"Date"', 'Oct 08'), ('Price', '85.63'), ('Open', '79.20'), ('High', '87.88'), ('Low', '78.95'), ('Vol.', '-'), ('Change %', '7.78%')])
# OrderedDict([('ï»¿"Date"', 'Sep 08'), ('Price', '79.45'), ('Open', '77.75'), ('High', '80.38'), ('Low', '75.89'), ('Vol.', '-'), ('Change %', '2.68%')])
# OrderedDict([('ï»¿"Date"', 'Aug 08'), ('Price', '77.38'), ('Open', '73.22'), ('High', '77.62'), ('Low', '73.20'), ('Vol.', '-'), ('Change %', '5.67%')])
# OrderedDict([('ï»¿"Date"', 'Jul 08'), ('Price', '73.23'), ('Open', '72.46'), ('High', '73.54'), ('Low', '71.31'), ('Vol.', '-'), ('Change %', '1.06%')])
# OrderedDict([('ï»¿"Date"', 'Jun 08'), ('Price', '72.46'), ('Open', '72.87'), ('High', '74.31'), ('Low', '72.04'), ('Vol.', '-'), ('Change %', '-0.58%')])
# OrderedDict([('ï»¿"Date"', 'May 08'), ('Price', '72.88'), ('Open', '72.57'), ('High', '73.89'), ('Low', '71.82'), ('Vol.', '-'), ('Change %', '0.51%')])
# OrderedDict([('ï»¿"Date"', 'Apr 08'), ('Price', '72.51'), ('Open', '71.87'), ('High', '73.11'), ('Low', '71.19'), ('Vol.', '-'), ('Change %', '0.99%')])
# OrderedDict([('ï»¿"Date"', 'Mar 08'), ('Price', '71.80'), ('Open', '73.75'), ('High', '73.95'), ('Low', '70.70'), ('Vol.', '-'), ('Change %', '-2.59%')])
# OrderedDict([('ï»¿"Date"', 'Feb 08'), ('Price', '73.71'), ('Open', '75.23'), ('High', '77.04'), ('Low', '73.56'), ('Vol.', '-'), ('Change %', '-1.96%')])
# OrderedDict([('ï»¿"Date"', 'Jan 08'), ('Price', '75.18'), ('Open', '76.35'), ('High', '77.35'), ('Low', '74.97'), ('Vol.', '-'), ('Change %', '-1.97%')])
# OrderedDict([('ï»¿"Date"', 'Dec 07'), ('Price', '76.69'), ('Open', '75.93'), ('High', '77.85'), ('Low', '75.59'), ('Vol.', '-'), ('Change %', '0.71%')])
# OrderedDict([('ï»¿"Date"', 'Nov 07'), ('Price', '76.15'), ('Open', '76.61'), ('High', '76.87'), ('Low', '74.48'), ('Vol.', '-'), ('Change %', '-0.43%')])
# OrderedDict([('ï»¿"Date"', 'Oct 07'), ('Price', '76.48'), ('Open', '77.79'), ('High', '78.89'), ('Low', '76.47'), ('Vol.', '-'), ('Change %', '-1.60%')])
# OrderedDict([('ï»¿"Date"', 'Sep 07'), ('Price', '77.72'), ('Open', '80.81'), ('High', '81.14'), ('Low', '77.67'), ('Vol.', '-'), ('Change %', '-3.80%')])
# OrderedDict([('ï»¿"Date"', 'Aug 07'), ('Price', '80.79'), ('Open', '80.90'), ('High', '82.13'), ('Low', '79.96'), ('Vol.', '-'), ('Change %', '0.02%')])
# OrderedDict([('ï»¿"Date"', 'Jul 07'), ('Price', '80.77'), ('Open', '81.87'), ('High', '81.95'), ('Low', '80.02'), ('Vol.', '-'), ('Change %', '-1.40%')])
# OrderedDict([('ï»¿"Date"', 'Jun 07'), ('Price', '81.92'), ('Open', '82.31'), ('High', '83.27'), ('Low', '81.70'), ('Vol.', '-'), ('Change %', '-0.46%')])
# OrderedDict([('ï»¿"Date"', 'May 07'), ('Price', '82.30'), ('Open', '81.42'), ('High', '82.60'), ('Low', '81.25'), ('Vol.', '-'), ('Change %', '1.04%')])
# OrderedDict([('ï»¿"Date"', 'Apr 07'), ('Price', '81.45'), ('Open', '82.91'), ('High', '83.21'), ('Low', '81.27'), ('Vol.', '-'), ('Change %', '-1.78%')])
# OrderedDict([('ï»¿"Date"', 'Mar 07'), ('Price', '82.93'), ('Open', '83.62'), ('High', '84.38'), ('Low', '82.64'), ('Vol.', '-'), ('Change %', '-0.77%')])
# OrderedDict([('ï»¿"Date"', 'Feb 07'), ('Price', '83.57'), ('Open', '84.65'), ('High', '85.21'), ('Low', '83.40'), ('Vol.', '-'), ('Change %', '-1.23%')])
# OrderedDict([('ï»¿"Date"', 'Jan 07'), ('Price', '84.61'), ('Open', '83.46'), ('High', '85.43'), ('Low', '83.15'), ('Vol.', '-'), ('Change %', '1.06%')])
# OrderedDict([('ï»¿"Date"', 'Dec 06'), ('Price', '83.72'), ('Open', '82.91'), ('High', '84.22'), ('Low', '82.24'), ('Vol.', '-'), ('Change %', '0.96%')])
# OrderedDict([('ï»¿"Date"', 'Nov 06'), ('Price', '82.92'), ('Open', '85.29'), ('High', '85.93'), ('Low', '82.79'), ('Vol.', '-'), ('Change %', '-2.81%')])
# OrderedDict([('ï»¿"Date"', 'Oct 06'), ('Price', '85.32'), ('Open', '86.01'), ('High', '87.30'), ('Low', '85.21'), ('Vol.', '-'), ('Change %', '-0.76%')])
# OrderedDict([('ï»¿"Date"', 'Sep 06'), ('Price', '85.97'), ('Open', '85.09'), ('High', '86.22'), ('Low', '84.73'), ('Vol.', '-'), ('Change %', '1.08%')])
# OrderedDict([('ï»¿"Date"', 'Aug 06'), ('Price', '85.05'), ('Open', '85.28'), ('High', '85.75'), ('Low', '84.39'), ('Vol.', '-'), ('Change %', '-0.29%')])
# OrderedDict([('ï»¿"Date"', 'Jul 06'), ('Price', '85.30'), ('Open', '85.20'), ('High', '87.33'), ('Low', '84.77'), ('Vol.', '-'), ('Change %', '0.09%')])
# OrderedDict([('ï»¿"Date"', 'Jun 06'), ('Price', '85.22'), ('Open', '84.68'), ('High', '87.05'), ('Low', '83.72'), ('Vol.', '-'), ('Change %', '0.59%')])
# OrderedDict([('ï»¿"Date"', 'May 06'), ('Price', '84.72'), ('Open', '85.93'), ('High', '86.36'), ('Low', '83.60'), ('Vol.', '-'), ('Change %', '-1.61%')])
# OrderedDict([('ï»¿"Date"', 'Apr 06'), ('Price', '86.11'), ('Open', '89.74'), ('High', '90.40'), ('Low', '86.00'), ('Vol.', '-'), ('Change %', '-4.03%')])
# OrderedDict([('ï»¿"Date"', 'Mar 06'), ('Price', '89.73'), ('Open', '90.08'), ('High', '91.16'), ('Low', '88.85'), ('Vol.', '-'), ('Change %', '-0.42%')])
# OrderedDict([('ï»¿"Date"', 'Feb 06'), ('Price', '90.11'), ('Open', '88.96'), ('High', '91.02'), ('Low', '88.84'), ('Vol.', '-'), ('Change %', '1.29%')])
# OrderedDict([('ï»¿"Date"', 'Jan 06'), ('Price', '88.96'), ('Open', '90.75'), ('High', '90.94'), ('Low', '87.83'), ('Vol.', '-'), ('Change %', '-2.42%')])
# OrderedDict([('ï»¿"Date"', 'Dec 05'), ('Price', '91.17'), ('Open', '91.54'), ('High', '92.32'), ('Low', '89.52'), ('Vol.', '-'), ('Change %', '-0.44%')])
# OrderedDict([('ï»¿"Date"', 'Nov 05'), ('Price', '91.57'), ('Open', '90.12'), ('High', '92.63'), ('Low', '89.62'), ('Vol.', '-'), ('Change %', '1.67%')])
# OrderedDict([('ï»¿"Date"', 'Oct 05'), ('Price', '90.07'), ('Open', '89.51'), ('High', '90.74'), ('Low', '88.53'), ('Vol.', '-'), ('Change %', '0.61%')])
# OrderedDict([('ï»¿"Date"', 'Sep 05'), ('Price', '89.52'), ('Open', '87.59'), ('High', '89.82'), ('Low', '86.02'), ('Vol.', '-'), ('Change %', '2.22%')])
# OrderedDict([('ï»¿"Date"', 'Aug 05'), ('Price', '87.58'), ('Open', '89.41'), ('High', '89.44'), ('Low', '86.76'), ('Vol.', '-'), ('Change %', '-1.98%')])
# OrderedDict([('ï»¿"Date"', 'Jul 05'), ('Price', '89.35'), ('Open', '89.17'), ('High', '90.77'), ('Low', '88.28'), ('Vol.', '-'), ('Change %', '0.27%')])
# OrderedDict([('ï»¿"Date"', 'Jun 05'), ('Price', '89.11'), ('Open', '87.74'), ('High', '89.48'), ('Low', '87.15'), ('Vol.', '-'), ('Change %', '1.54%')])
# OrderedDict([('ï»¿"Date"', 'May 05'), ('Price', '87.76'), ('Open', '84.46'), ('High', '87.80'), ('Low', '83.75'), ('Vol.', '-'), ('Change %', '3.94%')])
# OrderedDict([('ï»¿"Date"', 'Apr 05'), ('Price', '84.43'), ('Open', '84.07'), ('High', '85.32'), ('Low', '83.36'), ('Vol.', '-'), ('Change %', '0.44%')])
# OrderedDict([('ï»¿"Date"', 'Mar 05'), ('Price', '84.06'), ('Open', '82.65'), ('High', '84.74'), ('Low', '81.28'), ('Vol.', '-'), ('Change %', '1.88%')])
# OrderedDict([('ï»¿"Date"', 'Feb 05'), ('Price', '82.51'), ('Open', '83.49'), ('High', '85.44'), ('Low', '82.30'), ('Vol.', '-'), ('Change %', '-1.30%')])
# OrderedDict([('ï»¿"Date"', 'Jan 05'), ('Price', '83.60'), ('Open', '81.05'), ('High', '84.08'), ('Low', '80.77'), ('Vol.', '-'), ('Change %', '3.40%')])
# OrderedDict([('ï»¿"Date"', 'Dec 04'), ('Price', '80.85'), ('Open', '81.81'), ('High', '83.18'), ('Low', '80.39'), ('Vol.', '-'), ('Change %', '-1.19%')])
# OrderedDict([('ï»¿"Date"', 'Nov 04'), ('Price', '81.82'), ('Open', '84.70'), ('High', '85.66'), ('Low', '81.53'), ('Vol.', '-'), ('Change %', '-3.64%')])
# OrderedDict([('ï»¿"Date"', 'Oct 04'), ('Price', '84.91'), ('Open', '87.41'), ('High', '88.64'), ('Low', '84.73'), ('Vol.', '-'), ('Change %', '-2.80%')])
# OrderedDict([('ï»¿"Date"', 'Sep 04'), ('Price', '87.36'), ('Open', '88.91'), ('High', '89.75'), ('Low', '87.35'), ('Vol.', '-'), ('Change %', '-1.78%')])
# OrderedDict([('ï»¿"Date"', 'Aug 04'), ('Price', '88.94'), ('Open', '89.71'), ('High', '90.19'), ('Low', '87.66'), ('Vol.', '-'), ('Change %', '-1.13%')])
# OrderedDict([('ï»¿"Date"', 'Jul 04'), ('Price', '89.96'), ('Open', '88.84'), ('High', '90.29'), ('Low', '87.00'), ('Vol.', '-'), ('Change %', '1.31%')])
# OrderedDict([('ï»¿"Date"', 'Jun 04'), ('Price', '88.80'), ('Open', '88.64'), ('High', '90.42'), ('Low', '88.04'), ('Vol.', '-'), ('Change %', '-0.17%')])
# OrderedDict([('ï»¿"Date"', 'May 04'), ('Price', '88.95'), ('Open', '90.63'), ('High', '92.29'), ('Low', '88.47'), ('Vol.', '-'), ('Change %', '-1.69%')])
# OrderedDict([('ï»¿"Date"', 'Apr 04'), ('Price', '90.48'), ('Open', '87.57'), ('High', '91.56'), ('Low', '87.02'), ('Vol.', '-'), ('Change %', '3.28%')])
# OrderedDict([('ï»¿"Date"', 'Mar 04'), ('Price', '87.61'), ('Open', '87.10'), ('High', '89.84'), ('Low', '87.03'), ('Vol.', '-'), ('Change %', '0.34%')])
# OrderedDict([('ï»¿"Date"', 'Feb 04'), ('Price', '87.31'), ('Open', '87.14'), ('High', '88.02'), ('Low', '84.56'), ('Vol.', '-'), ('Change %', '0.13%')])
# OrderedDict([('ï»¿"Date"', 'Jan 04'), ('Price', '87.20'), ('Open', '86.79'), ('High', '88.07'), ('Low', '84.80'), ('Vol.', '-'), ('Change %', '0.32%')])
# OrderedDict([('ï»¿"Date"', 'Dec 03'), ('Price', '86.92'), ('Open', '90.16'), ('High', '90.54'), ('Low', '86.36'), ('Vol.', '-'), ('Change %', '-3.65%')])
# OrderedDict([('ï»¿"Date"', 'Nov 03'), ('Price', '90.21'), ('Open', '92.64'), ('High', '94.13'), ('Low', '90.04'), ('Vol.', '-'), ('Change %', '-2.72%')])
# OrderedDict([('ï»¿"Date"', 'Oct 03'), ('Price', '92.73'), ('Open', '92.73'), ('High', '93.42'), ('Low', '91.01'), ('Vol.', '-'), ('Change %', '-0.13%')])
# OrderedDict([('ï»¿"Date"', 'Sep 03'), ('Price', '92.85'), ('Open', '97.88'), ('High', '99.37'), ('Low', '92.10'), ('Vol.', '-'), ('Change %', '-5.35%')])
# OrderedDict([('ï»¿"Date"', 'Aug 03'), ('Price', '98.10'), ('Open', '96.87'), ('High', '99.49'), ('Low', '95.56'), ('Vol.', '-'), ('Change %', '1.25%')])
# OrderedDict([('ï»¿"Date"', 'Jul 03'), ('Price', '96.89'), ('Open', '94.54'), ('High', '97.45'), ('Low', '93.96'), ('Vol.', '-'), ('Change %', '2.28%')])
# OrderedDict([('ï»¿"Date"', 'Jun 03'), ('Price', '94.73'), ('Open', '93.73'), ('High', '95.34'), ('Low', '91.88'), ('Vol.', '-'), ('Change %', '1.57%')])
# OrderedDict([('ï»¿"Date"', 'May 03'), ('Price', '93.27'), ('Open', '97.18'), ('High', '97.25'), ('Low', '92.21'), ('Vol.', '-'), ('Change %', '-4.03%')])
# OrderedDict([('ï»¿"Date"', 'Apr 03'), ('Price', '97.19'), ('Open', '98.86'), ('High', '101.81'), ('Low', '97.10'), ('Vol.', '-'), ('Change %', '-1.89%')])
# OrderedDict([('ï»¿"Date"', 'Mar 03'), ('Price', '99.06'), ('Open', '99.74'), ('High', '102.15'), ('Low', '97.57'), ('Vol.', '-'), ('Change %', '-0.65%')])
# OrderedDict([('ï»¿"Date"', 'Feb 03'), ('Price', '99.71'), ('Open', '100.26'), ('High', '100.89'), ('Low', '98.65'), ('Vol.', '-'), ('Change %', '-0.20%')])
# OrderedDict([('ï»¿"Date"', 'Jan 03'), ('Price', '99.91'), ('Open', '102.36'), ('High', '103.20'), ('Low', '98.76'), ('Vol.', '-'), ('Change %', '-1.90%')])
# OrderedDict([('ï»¿"Date"', 'Dec 02'), ('Price', '101.85'), ('Open', '106.57'), ('High', '107.31'), ('Low', '101.82'), ('Vol.', '-'), ('Change %', '-4.29%')])
# OrderedDict([('ï»¿"Date"', 'Nov 02'), ('Price', '106.41'), ('Open', '106.55'), ('High', '106.97'), ('Low', '104.12'), ('Vol.', '-'), ('Change %', '-0.22%')])
# OrderedDict([('ï»¿"Date"', 'Oct 02'), ('Price', '106.64'), ('Open', '106.74'), ('High', '108.74'), ('Low', '106.54'), ('Vol.', '-'), ('Change %', '-0.22%')])
# OrderedDict([('ï»¿"Date"', 'Sep 02'), ('Price', '106.87'), ('Open', '106.43'), ('High', '109.67'), ('Low', '105.41'), ('Vol.', '-'), ('Change %', '-0.10%')])
# OrderedDict([('ï»¿"Date"', 'Aug 02'), ('Price', '106.98'), ('Open', '107.61'), ('High', '109.00'), ('Low', '106.18'), ('Vol.', '-'), ('Change %', '-0.40%')])
# OrderedDict([('ï»¿"Date"', 'Jul 02'), ('Price', '107.41'), ('Open', '105.76'), ('High', '107.88'), ('Low', '103.54'), ('Vol.', '-'), ('Change %', '1.23%')])
# OrderedDict([('ï»¿"Date"', 'Jun 02'), ('Price', '106.11'), ('Open', '111.93'), ('High', '112.04'), ('Low', '105.37'), ('Vol.', '-'), ('Change %', '-5.10%')])
# OrderedDict([('ï»¿"Date"', 'May 02'), ('Price', '111.81'), ('Open', '115.18'), ('High', '115.34'), ('Low', '110.88'), ('Vol.', '-'), ('Change %', '-2.93%')])
# OrderedDict([('ï»¿"Date"', 'Apr 02'), ('Price', '115.19'), ('Open', '118.56'), ('High', '118.70'), ('Low', '114.72'), ('Vol.', '-'), ('Change %', '-2.89%')])
# OrderedDict([('ï»¿"Date"', 'Mar 02'), ('Price', '118.62'), ('Open', '119.29'), ('High', '119.61'), ('Low', '116.76'), ('Vol.', '-'), ('Change %', '-0.45%')])
# OrderedDict([('ï»¿"Date"', 'Feb 02'), ('Price', '119.16'), ('Open', '120.21'), ('High', '120.40'), ('Low', '118.09'), ('Vol.', '-'), ('Change %', '-0.90%')])
# OrderedDict([('ï»¿"Date"', 'Jan 02'), ('Price', '120.24'), ('Open', '116.40'), ('High', '120.51'), ('Low', '115.54'), ('Vol.', '-'), ('Change %', '2.99%')])
# OrderedDict([('ï»¿"Date"', 'Dec 01'), ('Price', '116.75'), ('Open', '115.61'), ('High', '118.26'), ('Low', '114.43'), ('Vol.', '-'), ('Change %', '0.53%')])
# OrderedDict([('ï»¿"Date"', 'Nov 01'), ('Price', '116.13'), ('Open', '114.71'), ('High', '117.43'), ('Low', '113.66'), ('Vol.', '-'), ('Change %', '1.11%')])
# OrderedDict([('ï»¿"Date"', 'Oct 01'), ('Price', '114.86'), ('Open', '113.69'), ('High', '116.27'), ('Low', '112.27'), ('Vol.', '-'), ('Change %', '1.22%')])
# OrderedDict([('ï»¿"Date"', 'Sep 01'), ('Price', '113.48'), ('Open', '113.48'), ('High', '116.08'), ('Low', '111.31'), ('Vol.', '-'), ('Change %', '0.05%')])
# OrderedDict([('ï»¿"Date"', 'Aug 01'), ('Price', '113.42'), ('Open', '117.07'), ('High', '117.16'), ('Low', '112.32'), ('Vol.', '-'), ('Change %', '-3.21%')])
# OrderedDict([('ï»¿"Date"', 'Jul 01'), ('Price', '117.18'), ('Open', '119.39'), ('High', '121.02'), ('Low', '116.34'), ('Vol.', '-'), ('Change %', '-1.88%')])
# OrderedDict([('ï»¿"Date"', 'Jun 01'), ('Price', '119.43'), ('Open', '119.11'), ('High', '120.33'), ('Low', '117.43'), ('Vol.', '-'), ('Change %', '0.30%')])
# OrderedDict([('ï»¿"Date"', 'May 01'), ('Price', '119.07'), ('Open', '115.71'), ('High', '119.29'), ('Low', '114.27'), ('Vol.', '-'), ('Change %', '2.78%')])
# OrderedDict([('ï»¿"Date"', 'Apr 01'), ('Price', '115.85'), ('Open', '117.70'), ('High', '117.82'), ('Low', '113.86'), ('Vol.', '-'), ('Change %', '-1.30%')])
# OrderedDict([('ï»¿"Date"', 'Mar 01'), ('Price', '117.37'), ('Open', '112.04'), ('High', '117.63'), ('Low', '110.82'), ('Vol.', '-'), ('Change %', '4.79%')])
# OrderedDict([('ï»¿"Date"', 'Feb 01'), ('Price', '112.01'), ('Open', '110.30'), ('High', '113.62'), ('Low', '109.40'), ('Vol.', '-'), ('Change %', '1.35%')])
# OrderedDict([('ï»¿"Date"', 'Jan 01'), ('Price', '110.52'), ('Open', '109.33'), ('High', '112.65'), ('Low', '108.09'), ('Vol.', '-'), ('Change %', '0.88%')])
# OrderedDict([('ï»¿"Date"', 'Dec 00'), ('Price', '109.56'), ('Open', '115.21'), ('High', '115.44'), ('Low', '109.46'), ('Vol.', '-'), ('Change %', '-4.93%')])
# OrderedDict([('ï»¿"Date"', 'Nov 00'), ('Price', '115.24'), ('Open', '116.60'), ('High', '118.69'), ('Low', '112.75'), ('Vol.', '-'), ('Change %', '-1.21%')])
# OrderedDict([('ï»¿"Date"', 'Oct 00'), ('Price', '116.65'), ('Open', '113.14'), ('High', '119.07'), ('Low', '112.95'), ('Vol.', '-'), ('Change %', '3.00%')])
# OrderedDict([('ï»¿"Date"', 'Sep 00'), ('Price', '113.25'), ('Open', '112.36'), ('High', '116.75'), ('Low', '111.25'), ('Vol.', '-'), ('Change %', '0.58%')])
# OrderedDict([('ï»¿"Date"', 'Aug 00'), ('Price', '112.60'), ('Open', '109.50'), ('High', '112.93'), ('Low', '109.35'), ('Vol.', '-'), ('Change %', '2.77%')])

# %%
precio = []
fecha = []
with open('USDMensual.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        fecha.append(row['ï»¿"Date"'])
        precio.append(float(row['Price'].replace("'","")))

# %%
# Podemos ver que los datos no están ordenados cronológicamente, por lo que tenemos que reordenarlos, dándolos vuelta

precio.reverse()
fecha.reverse()

# %%
print(fecha)
# Out:
# ['Aug 00', 'Sep 00', 'Oct 00', 'Nov 00', 'Dec 00', 'Jan 01', 'Feb 01', 'Mar 01', 'Apr 01', 'May 01', 'Jun 01', 'Jul 01', 'Aug 01', 'Sep 01', 'Oct 01', 'Nov 01', 'Dec 01', 'Jan 02', 'Feb 02', 'Mar 02', 'Apr 02', 'May 02', 'Jun 02', 'Jul 02', 'Aug 02', 'Sep 02', 'Oct 02', 'Nov 02', 'Dec 02', 'Jan 03', 'Feb 03', 'Mar 03', 'Apr 03', 'May 03', 'Jun 03', 'Jul 03', 'Aug 03', 'Sep 03', 'Oct 03', 'Nov 03', 'Dec 03', 'Jan 04', 'Feb 04', 'Mar 04', 'Apr 04', 'May 04', 'Jun 04', 'Jul 04', 'Aug 04', 'Sep 04', 'Oct 04', 'Nov 04', 'Dec 04', 'Jan 05', 'Feb 05', 'Mar 05', 'Apr 05', 'May 05', 'Jun 05', 'Jul 05', 'Aug 05', 'Sep 05', 'Oct 05', 'Nov 05', 'Dec 05', 'Jan 06', 'Feb 06', 'Mar 06', 'Apr 06', 'May 06', 'Jun 06', 'Jul 06', 'Aug 06', 'Sep 06', 'Oct 06', 'Nov 06', 'Dec 06', 'Jan 07', 'Feb 07', 'Mar 07', 'Apr 07', 'May 07', 'Jun 07', 'Jul 07', 'Aug 07', 'Sep 07', 'Oct 07', 'Nov 07', 'Dec 07', 'Jan 08', 'Feb 08', 'Mar 08', 'Apr 08', 'May 08', 'Jun 08', 'Jul 08', 'Aug 08', 'Sep 08', 'Oct 08', 'Nov 08', 'Dec 08', 'Jan 09', 'Feb 09', 'Mar 09', 'Apr 09', 'May 09', 'Jun 09', 'Jul 09', 'Aug 09', 'Sep 09', 'Oct 09', 'Nov 09', 'Dec 09', 'Jan 10', 'Feb 10', 'Mar 10', 'Apr 10', 'May 10', 'Jun 10', 'Jul 10', 'Aug 10', 'Sep 10', 'Oct 10', 'Nov 10', 'Dec 10', 'Jan 11', 'Feb 11', 'Mar 11', 'Apr 11', 'May 11', 'Jun 11', 'Jul 11', 'Aug 11', 'Sep 11', 'Oct 11', 'Nov 11', 'Dec 11', 'Jan 12', 'Feb 12', 'Mar 12', 'Apr 12', 'May 12', 'Jun 12', 'Jul 12', 'Aug 12', 'Sep 12', 'Oct 12', 'Nov 12', 'Dec 12', 'Jan 13', 'Feb 13', 'Mar 13', 'Apr 13', 'May 13', 'Jun 13', 'Jul 13', 'Aug 13', 'Sep 13', 'Oct 13', 'Nov 13', 'Dec 13', 'Jan 14', 'Feb 14', 'Mar 14', 'Apr 14', 'May 14', 'Jun 14', 'Jul 14', 'Aug 14', 'Sep 14', 'Oct 14', 'Nov 14', 'Dec 14', 'Jan 15', 'Feb 15', 'Mar 15', 'Apr 15', 'May 15', 'Jun 15', 'Jul 15', 'Aug 15', 'Sep 15', 'Oct 15', 'Nov 15', 'Dec 15', 'Jan 16', 'Feb 16', 'Mar 16', 'Apr 16', 'May 16', 'Jun 16', 'Jul 16', 'Aug 16', 'Sep 16', 'Oct 16', 'Nov 16', 'Dec 16', 'Jan 17', 'Feb 17', 'Mar 17', 'Apr 17', 'May 17', 'Jun 17', 'Jul 17', 'Aug 17', 'Sep 17', 'Oct 17', 'Nov 17', 'Dec 17', 'Jan 18', 'Feb 18', 'Mar 18', 'Apr 18', 'May 18', 'Jun 18', 'Jul 18', 'Aug 18', 'Sep 18', 'Oct 18', 'Nov 18', 'Dec 18', 'Jan 19', 'Feb 19', 'Mar 19', 'Apr 19', 'May 19', 'Jun 19', 'Jul 19', 'Aug 19', 'Sep 19', 'Oct 19', 'Nov 19', 'Dec 19', 'Jan 20', 'Feb 20', 'Mar 20', 'Apr 20', 'May 20', 'Jun 20', 'Jul 20']

# %%
# Como el arreglo fecha no es numérico, creamos uno que sí lo sea y lo pueda representar

mes1 = 2000 + 8 / 12
mes2 = 2020 + 7 / 12

fechas = np.arange(mes1, mes2 + 1 / 12, 1/12)

# %%
fig = plt.figure(figsize=(8, 5))
plt.plot(fechas, precio, 'b')
plt.xlabel('Año')
plt.ylabel('Índice del dólar')
plt.title('Registro mensual de índice del dólar')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
from scipy.interpolate import interp1d


f2 = interp1d(fechas, precio, kind='cubic')

# %%
# Evaluamos las fechas en la función spline que calculamos

precios_knots = f2(fechas)

# %%
# Vemos que el spline efectivamente pasa por todos los puntos observados en el registro

fig2 = plt.figure(figsize=(8, 5))

plt.plot(fechas, precio, 'b', label='Datos')
plt.plot(fechas, precios_knots, 'r', marker='.', markersize=3, linestyle='', label='Spline')
plt.xlabel('Año')
plt.ylabel('Índice del dólar')
plt.title('Nudos de spline cúbico sobre datos')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# Evitamos evaluar el spline en los extremos del arreglo (cosas que pasan)

fechas_spline_semana = np.linspace(mes1 + 1 / 12, mes2 - 1 / 12, 100000)
precios_spline_semana = f2(fechas_spline_semana)

# %%
fig3 = plt.figure(figsize=(8, 5))

plt.plot(fechas_spline_semana, precios_spline_semana, 'r', label='Spline', linewidth=1)
plt.plot(fechas, precio, '.b', label='Registro mensual', markersize=2)
plt.legend()
plt.xlabel('Año')
plt.ylabel('Índice del dólar')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# Leemos ahora los datos semanales

preciosem = []
fechasem = []
with open('USDSemanal.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        fechasem.append(row['ï»¿"Date"'])
        #precio.append(row['Price'])
        preciosem.append(float(row['Price'].replace("'","")))

# %%
preciosem.reverse()
fechasem.reverse()

# %%
sem1 = 2010 + 2 / (52)
sem2 = 2010 + 27 / (52)
fechassem = np.linspace(sem1, sem2, len(fechasem))

# %%
fig4 = plt.figure(figsize=(9, 4))
ax1 = None
ax2 = None

# Gráfico de arriba
ax1 = plt.subplot2grid((1, 8), (0, 0), colspan=6, fig=fig4)
ax1 = plt.plot(fechas_spline_semana, precios_spline_semana, color='red',label='Spline cúbico Reg. mensual' , linewidth=1)
ax1 = plt.plot(fechassem, preciosem, color='blue', label='Reg. semanal', linestyle='', marker='.', markersize=3)
plt.xlabel('Año')
plt.ylabel('Índice del dólar')
plt.legend()

ax2 = plt.subplot2grid((1, 8), (0, 6), colspan=2, fig=fig4)
ax2.set_xlim((2009.5, 2011))
ax2 = plt.plot(fechas_spline_semana, precios_spline_semana, color='red',label='Spline cúbico Reg. mensual' , linewidth=1)
ax2 = plt.plot(fechassem, np.asarray(preciosem), color='blue', label='Reg. semanal', linestyle='', marker='.', markersize=3)
plt.xlabel('Año')

fig4.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# ## Ejercicios
#
# **1.-** Utilice distintas funciones (por ejemplo, las definidas en laboratorios anteriores) y pruebe los módulos del Método de Descenso Máximo y de Newton. Si quisiera encontrar un máximo en lugar de un mínimo, ¿cómo tendría que cambiar estar funciones?
#
# **2.-** Lea el archivo USDDiario.csv y compare gráficamente los datos con los interpolados de los datos mensuales. Note que, para definir los valores dia1 y dia2 (tal como mes1, mes2 o semana1, semana2), tiene que definirlos como
# ```Python
# dia1 = año + numero_de_dia_1_en_relacion_con_el_año / 365.25
# dia1 = año + numero_de_dia_2_en_relacion_con_el_año / 365.25
# ```
# Por ejemplo, si su primer dato es del 4 de marzo del 2019, el día 4 de marzo corresponde al día $31+28+4=63$ del año (ojo en caso de que el año sea bisiesto). Pruebe además distintos tipos de interpolación, para lo cual puede revisar la documentación de <a href='https://docs.scipy.org/doc/scipy/reference/generated/scipy.interpolate.interp1d.html#scipy.interpolate.interp1d'>interp1d</a>.
